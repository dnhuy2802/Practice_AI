# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
from torch import nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader

device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
torch.manual_seed(42)
# Out:
# /home/huydn/miniconda3/envs/torch/lib/python3.11/site-packages/torch/cuda/__init__.py:138: UserWarning: CUDA initialization: CUDA unknown error - this may be due to an incorrectly set up environment, e.g. changing env variable CUDA_VISIBLE_DEVICES after program start. Setting the available devices to be zero. (Triggered internally at ../c10/cuda/CUDAFunctions.cpp:108.)
#   return torch._C._cuda_getDeviceCount() > 0

# %% [markdown]
# ## Load Data

# %%
data_path = "data/NonLinear_data.npy"
data = np.load(data_path, allow_pickle=True).item()
X, labels = data["X"], data["labels"]
X, labels = torch.tensor(X, dtype=torch.float32), torch.tensor(labels, dtype=torch.long)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
class CustomDataset(Dataset):
    def __init__(self, X, y):
        self.X = X
        self.y = y

    def __len__(self):
        return len(self.y)

    def __getitem__(self, idx):
        # print(idx)
        return self.X[idx], self.y[idx]

# %%
train_dataset = CustomDataset(X, labels)
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)

# %% [markdown]
# ## Use Pytorch to build, compile and train and evaluate the model
# The results of training and evaluation are presented graphically using matplotlib

# %% [markdown]
# ### Softmax Regression

# %%
# Thiết kế model theo yêu cầu đề  bài 
# Linear layer in_features = input_dims (2), out_features = num_classes (3)

class SoftMaxRegression(nn.Module):
    def __init__(self, input_dims, num_classes):
        super(SoftMaxRegression, self).__init__()
        self.linear = nn.Linear(input_dims, num_classes)

    def forward(self, x):
        x = self.linear(x)
        return x

model = SoftMaxRegression(input_dims=2, num_classes=3).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.1)

# %%
num_epochs = 200
train_losses = []
train_acc = []

for epoch in range(num_epochs):
    model.train()
    train_loss = 0.0
    accuracy = 0
    cnt = 0
    for X, y in train_loader:
        X, y = X.to(device), y.to(device)
        optimizer.zero_grad()
        outputs = model(X)
        loss = criterion(outputs, y)
        loss.backward()
        optimizer.step()
        train_loss += loss.item()
        accuracy += (torch.argmax(outputs, 1) == y).sum().item()
        cnt += len(y)
    train_loss /= len(train_loader)
    train_losses.append(train_loss)
    accuracy /= cnt
    train_acc.append(accuracy)

    print(f"Epoch {epoch+1}/{num_epochs}, Train_Loss: {train_loss:.4f},  Train_Acc: {accuracy:.4f}")
# Out:
# Epoch 1/200, Train_Loss: 1.1106,  Train_Acc: 0.4467
# Epoch 2/200, Train_Loss: 1.0762,  Train_Acc: 0.4633
# Epoch 3/200, Train_Loss: 1.0331,  Train_Acc: 0.4667
# Epoch 4/200, Train_Loss: 1.0022,  Train_Acc: 0.5333
# Epoch 5/200, Train_Loss: 0.9762,  Train_Acc: 0.5667
# Epoch 6/200, Train_Loss: 0.9578,  Train_Acc: 0.5700
# Epoch 7/200, Train_Loss: 0.9458,  Train_Acc: 0.5400
# Epoch 8/200, Train_Loss: 0.9235,  Train_Acc: 0.5333
# Epoch 9/200, Train_Loss: 0.9158,  Train_Acc: 0.5267
# Epoch 10/200, Train_Loss: 0.9020,  Train_Acc: 0.5200
# Epoch 11/200, Train_Loss: 0.8903,  Train_Acc: 0.5267
# Epoch 12/200, Train_Loss: 0.8763,  Train_Acc: 0.5200
# Epoch 13/200, Train_Loss: 0.8696,  Train_Acc: 0.5100
# Epoch 14/200, Train_Loss: 0.8693,  Train_Acc: 0.5233
# Epoch 15/200, Train_Loss: 0.8601,  Train_Acc: 0.5333
# Epoch 16/200, Train_Loss: 0.8523,  Train_Acc: 0.5300
# Epoch 17/200, Train_Loss: 0.8413,  Train_Acc: 0.5433
# Epoch 18/200, Train_Loss: 0.8375,  Train_Acc: 0.5300
# Epoch 19/200, Train_Loss: 0.8423,  Train_Acc: 0.5400
# Epoch 20/200, Train_Loss: 0.8222,  Train_Acc: 0.5433
# Epoch 21/200, Train_Loss: 0.8304,  Train_Acc: 0.5367
# Epoch 22/200, Train_Loss: 0.8090,  Train_Acc: 0.5333
# Epoch 23/200, Train_Loss: 0.8175,  Train_Acc: 0.5333
# Epoch 24/200, Train_Loss: 0.8171,  Train_Acc: 0.5267
# Epoch 25/200, Train_Loss: 0.8146,  Train_Acc: 0.5267
# Epoch 26/200, Train_Loss: 0.8047,  Train_Acc: 0.5233
# Epoch 27/200, Train_Loss: 0.7985,  Train_Acc: 0.5200
# Epoch 28/200, Train_Loss: 0.8087,  Train_Acc: 0.5133
# Epoch 29/200, Train_Loss: 0.8010,  Train_Acc: 0.5233
# Epoch 30/200, Train_Loss: 0.7882,  Train_Acc: 0.5267
# Epoch 31/200, Train_Loss: 0.7945,  Train_Acc: 0.5267
# Epoch 32/200, Train_Loss: 0.7905,  Train_Acc: 0.5200
# Epoch 33/200, Train_Loss: 0.7893,  Train_Acc: 0.5267
# Epoch 34/200, Train_Loss: 0.7822,  Train_Acc: 0.5267
# Epoch 35/200, Train_Loss: 0.7876,  Train_Acc: 0.5167
# Epoch 36/200, Train_Loss: 0.8063,  Train_Acc: 0.5300
# Epoch 37/200, Train_Loss: 0.7744,  Train_Acc: 0.5267
# Epoch 38/200, Train_Loss: 0.7682,  Train_Acc: 0.5233
# Epoch 39/200, Train_Loss: 0.7806,  Train_Acc: 0.5233
# Epoch 40/200, Train_Loss: 0.7829,  Train_Acc: 0.5233
# Epoch 41/200, Train_Loss: 0.7654,  Train_Acc: 0.5200
# Epoch 42/200, Train_Loss: 0.7779,  Train_Acc: 0.5233
# Epoch 43/200, Train_Loss: 0.7763,  Train_Acc: 0.5233
# Epoch 44/200, Train_Loss: 0.7781,  Train_Acc: 0.5300
# Epoch 45/200, Train_Loss: 0.7751,  Train_Acc: 0.5267
# Epoch 46/200, Train_Loss: 0.7664,  Train_Acc: 0.5267
# Epoch 47/200, Train_Loss: 0.7739,  Train_Acc: 0.5233
# Epoch 48/200, Train_Loss: 0.7657,  Train_Acc: 0.5200
# Epoch 49/200, Train_Loss: 0.7641,  Train_Acc: 0.5233
# Epoch 50/200, Train_Loss: 0.7692,  Train_Acc: 0.5233
# Epoch 51/200, Train_Loss: 0.7572,  Train_Acc: 0.5267
# Epoch 52/200, Train_Loss: 0.7551,  Train_Acc: 0.5267
# Epoch 53/200, Train_Loss: 0.7800,  Train_Acc: 0.5200
# Epoch 54/200, Train_Loss: 0.7751,  Train_Acc: 0.5233
# Epoch 55/200, Train_Loss: 0.7663,  Train_Acc: 0.5300
# Epoch 56/200, Train_Loss: 0.7661,  Train_Acc: 0.5300
# Epoch 57/200, Train_Loss: 0.7746,  Train_Acc: 0.5300
# Epoch 58/200, Train_Loss: 0.7460,  Train_Acc: 0.5267
# Epoch 59/200, Train_Loss: 0.7609,  Train_Acc: 0.5300
# Epoch 60/200, Train_Loss: 0.7600,  Train_Acc: 0.5200
# Epoch 61/200, Train_Loss: 0.7557,  Train_Acc: 0.5300
# Epoch 62/200, Train_Loss: 0.7446,  Train_Acc: 0.5233
# Epoch 63/200, Train_Loss: 0.7732,  Train_Acc: 0.5267
# Epoch 64/200, Train_Loss: 0.7510,  Train_Acc: 0.5233
# Epoch 65/200, Train_Loss: 0.7500,  Train_Acc: 0.5200
# Epoch 66/200, Train_Loss: 0.7700,  Train_Acc: 0.5267
# Epoch 67/200, Train_Loss: 0.7500,  Train_Acc: 0.5267
# Epoch 68/200, Train_Loss: 0.7564,  Train_Acc: 0.5267
# Epoch 69/200, Train_Loss: 0.7549,  Train_Acc: 0.5200
# Epoch 70/200, Train_Loss: 0.7459,  Train_Acc: 0.5200
# Epoch 71/200, Train_Loss: 0.7544,  Train_Acc: 0.5200
# Epoch 72/200, Train_Loss: 0.7534,  Train_Acc: 0.5233
# Epoch 73/200, Train_Loss: 0.7483,  Train_Acc: 0.5267
# Epoch 74/200, Train_Loss: 0.7456,  Train_Acc: 0.5200
# Epoch 75/200, Train_Loss: 0.7583,  Train_Acc: 0.5300
# Epoch 76/200, Train_Loss: 0.7481,  Train_Acc: 0.5267
# Epoch 77/200, Train_Loss: 0.7437,  Train_Acc: 0.5233
# Epoch 78/200, Train_Loss: 0.7473,  Train_Acc: 0.5233
# Epoch 79/200, Train_Loss: 0.7459,  Train_Acc: 0.5200
# Epoch 80/200, Train_Loss: 0.7470,  Train_Acc: 0.5233
# Epoch 81/200, Train_Loss: 0.7482,  Train_Acc: 0.5200
# Epoch 82/200, Train_Loss: 0.7285,  Train_Acc: 0.5267
# Epoch 83/200, Train_Loss: 0.7569,  Train_Acc: 0.5200
# Epoch 84/200, Train_Loss: 0.7524,  Train_Acc: 0.5167
# Epoch 85/200, Train_Loss: 0.7475,  Train_Acc: 0.5200
# Epoch 86/200, Train_Loss: 0.7327,  Train_Acc: 0.5200
# Epoch 87/200, Train_Loss: 0.7568,  Train_Acc: 0.5200
# Epoch 88/200, Train_Loss: 0.7647,  Train_Acc: 0.5267
# Epoch 89/200, Train_Loss: 0.7380,  Train_Acc: 0.5267
# Epoch 90/200, Train_Loss: 0.7300,  Train_Acc: 0.5267
# Epoch 91/200, Train_Loss: 0.7539,  Train_Acc: 0.5333
# Epoch 92/200, Train_Loss: 0.7525,  Train_Acc: 0.5267
# Epoch 93/200, Train_Loss: 0.7589,  Train_Acc: 0.5267
# Epoch 94/200, Train_Loss: 0.7442,  Train_Acc: 0.5333
# Epoch 95/200, Train_Loss: 0.7285,  Train_Acc: 0.5267
# Epoch 96/200, Train_Loss: 0.7459,  Train_Acc: 0.5267
# Epoch 97/200, Train_Loss: 0.7469,  Train_Acc: 0.5300
# Epoch 98/200, Train_Loss: 0.7469,  Train_Acc: 0.5300
# Epoch 99/200, Train_Loss: 0.7459,  Train_Acc: 0.5233
# Epoch 100/200, Train_Loss: 0.7338,  Train_Acc: 0.5233
# Epoch 101/200, Train_Loss: 0.7553,  Train_Acc: 0.5233
# Epoch 102/200, Train_Loss: 0.7440,  Train_Acc: 0.5267
# Epoch 103/200, Train_Loss: 0.7459,  Train_Acc: 0.5200
# Epoch 104/200, Train_Loss: 0.7531,  Train_Acc: 0.5300
# Epoch 105/200, Train_Loss: 0.7744,  Train_Acc: 0.5233
# Epoch 106/200, Train_Loss: 0.7459,  Train_Acc: 0.5300
# Epoch 107/200, Train_Loss: 0.7442,  Train_Acc: 0.5300
# Epoch 108/200, Train_Loss: 0.7432,  Train_Acc: 0.5300
# Epoch 109/200, Train_Loss: 0.7499,  Train_Acc: 0.5300
# Epoch 110/200, Train_Loss: 0.7483,  Train_Acc: 0.5267
# Epoch 111/200, Train_Loss: 0.7339,  Train_Acc: 0.5333
# Epoch 112/200, Train_Loss: 0.7491,  Train_Acc: 0.5267
# Epoch 113/200, Train_Loss: 0.7507,  Train_Acc: 0.5300
# Epoch 114/200, Train_Loss: 0.7513,  Train_Acc: 0.5300
# Epoch 115/200, Train_Loss: 0.7676,  Train_Acc: 0.5267
# Epoch 116/200, Train_Loss: 0.7339,  Train_Acc: 0.5267
# Epoch 117/200, Train_Loss: 0.7263,  Train_Acc: 0.5267
# Epoch 118/200, Train_Loss: 0.7671,  Train_Acc: 0.5267
# Epoch 119/200, Train_Loss: 0.7415,  Train_Acc: 0.5233
# Epoch 120/200, Train_Loss: 0.7359,  Train_Acc: 0.5233
# Epoch 121/200, Train_Loss: 0.7248,  Train_Acc: 0.5200
# Epoch 122/200, Train_Loss: 0.7416,  Train_Acc: 0.5300
# Epoch 123/200, Train_Loss: 0.7442,  Train_Acc: 0.5300
# Epoch 124/200, Train_Loss: 0.7386,  Train_Acc: 0.5267
# Epoch 125/200, Train_Loss: 0.7463,  Train_Acc: 0.5233
# Epoch 126/200, Train_Loss: 0.7438,  Train_Acc: 0.5200
# Epoch 127/200, Train_Loss: 0.7379,  Train_Acc: 0.5200
# Epoch 128/200, Train_Loss: 0.7365,  Train_Acc: 0.5233
# Epoch 129/200, Train_Loss: 0.7370,  Train_Acc: 0.5233
# Epoch 130/200, Train_Loss: 0.7550,  Train_Acc: 0.5233
# Epoch 131/200, Train_Loss: 0.7581,  Train_Acc: 0.5233
# Epoch 132/200, Train_Loss: 0.7471,  Train_Acc: 0.5267
# Epoch 133/200, Train_Loss: 0.7472,  Train_Acc: 0.5267
# Epoch 134/200, Train_Loss: 0.7437,  Train_Acc: 0.5300
# Epoch 135/200, Train_Loss: 0.7495,  Train_Acc: 0.5233
# Epoch 136/200, Train_Loss: 0.7496,  Train_Acc: 0.5200
# Epoch 137/200, Train_Loss: 0.7389,  Train_Acc: 0.5233
# Epoch 138/200, Train_Loss: 0.7527,  Train_Acc: 0.5267
# Epoch 139/200, Train_Loss: 0.7555,  Train_Acc: 0.5200
# Epoch 140/200, Train_Loss: 0.7510,  Train_Acc: 0.5233
# Epoch 141/200, Train_Loss: 0.7456,  Train_Acc: 0.5233
# Epoch 142/200, Train_Loss: 0.7514,  Train_Acc: 0.5233
# Epoch 143/200, Train_Loss: 0.7578,  Train_Acc: 0.5267
# Epoch 144/200, Train_Loss: 0.7601,  Train_Acc: 0.5200
# Epoch 145/200, Train_Loss: 0.7328,  Train_Acc: 0.5233
# Epoch 146/200, Train_Loss: 0.7387,  Train_Acc: 0.5233
# Epoch 147/200, Train_Loss: 0.7371,  Train_Acc: 0.5233
# Epoch 148/200, Train_Loss: 0.7569,  Train_Acc: 0.5267
# Epoch 149/200, Train_Loss: 0.7442,  Train_Acc: 0.5267
# Epoch 150/200, Train_Loss: 0.7406,  Train_Acc: 0.5233
# Epoch 151/200, Train_Loss: 0.7441,  Train_Acc: 0.5233
# Epoch 152/200, Train_Loss: 0.7387,  Train_Acc: 0.5200
# Epoch 153/200, Train_Loss: 0.7392,  Train_Acc: 0.5267
# Epoch 154/200, Train_Loss: 0.7431,  Train_Acc: 0.5233
# Epoch 155/200, Train_Loss: 0.7395,  Train_Acc: 0.5267
# Epoch 156/200, Train_Loss: 0.7455,  Train_Acc: 0.5200
# Epoch 157/200, Train_Loss: 0.7299,  Train_Acc: 0.5233
# Epoch 158/200, Train_Loss: 0.7481,  Train_Acc: 0.5233
# Epoch 159/200, Train_Loss: 0.7589,  Train_Acc: 0.5267
# Epoch 160/200, Train_Loss: 0.7407,  Train_Acc: 0.5267
# Epoch 161/200, Train_Loss: 0.7504,  Train_Acc: 0.5233
# Epoch 162/200, Train_Loss: 0.7388,  Train_Acc: 0.5267
# Epoch 163/200, Train_Loss: 0.7555,  Train_Acc: 0.5233
# Epoch 164/200, Train_Loss: 0.7575,  Train_Acc: 0.5267
# Epoch 165/200, Train_Loss: 0.7210,  Train_Acc: 0.5233
# Epoch 166/200, Train_Loss: 0.7631,  Train_Acc: 0.5267
# Epoch 167/200, Train_Loss: 0.7628,  Train_Acc: 0.5267
# Epoch 168/200, Train_Loss: 0.7354,  Train_Acc: 0.5233
# Epoch 169/200, Train_Loss: 0.7413,  Train_Acc: 0.5300
# Epoch 170/200, Train_Loss: 0.7501,  Train_Acc: 0.5233
# Epoch 171/200, Train_Loss: 0.7548,  Train_Acc: 0.5233
# Epoch 172/200, Train_Loss: 0.7227,  Train_Acc: 0.5233
# Epoch 173/200, Train_Loss: 0.7573,  Train_Acc: 0.5267
# Epoch 174/200, Train_Loss: 0.7474,  Train_Acc: 0.5300
# Epoch 175/200, Train_Loss: 0.7354,  Train_Acc: 0.5267
# Epoch 176/200, Train_Loss: 0.7507,  Train_Acc: 0.5233
# Epoch 177/200, Train_Loss: 0.7235,  Train_Acc: 0.5233
# Epoch 178/200, Train_Loss: 0.7407,  Train_Acc: 0.5267
# Epoch 179/200, Train_Loss: 0.7359,  Train_Acc: 0.5267
# Epoch 180/200, Train_Loss: 0.7485,  Train_Acc: 0.5267
# Epoch 181/200, Train_Loss: 0.7374,  Train_Acc: 0.5267
# Epoch 182/200, Train_Loss: 0.7504,  Train_Acc: 0.5267
# Epoch 183/200, Train_Loss: 0.7533,  Train_Acc: 0.5267
# Epoch 184/200, Train_Loss: 0.7458,  Train_Acc: 0.5267
# Epoch 185/200, Train_Loss: 0.7504,  Train_Acc: 0.5300
# Epoch 186/200, Train_Loss: 0.7498,  Train_Acc: 0.5267
# Epoch 187/200, Train_Loss: 0.7319,  Train_Acc: 0.5300
# Epoch 188/200, Train_Loss: 0.7334,  Train_Acc: 0.5300
# Epoch 189/200, Train_Loss: 0.7431,  Train_Acc: 0.5267
# Epoch 190/200, Train_Loss: 0.7366,  Train_Acc: 0.5233
# Epoch 191/200, Train_Loss: 0.7419,  Train_Acc: 0.5233
# Epoch 192/200, Train_Loss: 0.7454,  Train_Acc: 0.5267
# Epoch 193/200, Train_Loss: 0.7431,  Train_Acc: 0.5267
# Epoch 194/200, Train_Loss: 0.7388,  Train_Acc: 0.5300
# Epoch 195/200, Train_Loss: 0.7672,  Train_Acc: 0.5300
# Epoch 196/200, Train_Loss: 0.7324,  Train_Acc: 0.5233
# Epoch 197/200, Train_Loss: 0.7471,  Train_Acc: 0.5233
# Epoch 198/200, Train_Loss: 0.7417,  Train_Acc: 0.5233
# Epoch 199/200, Train_Loss: 0.7491,  Train_Acc: 0.5300
# Epoch 200/200, Train_Loss: 0.7481,  Train_Acc: 0.5267

# %%
fig = plt.figure(figsize=(12,4))
plt.subplot(1, 2, 1)
plt.plot(train_losses, label='loss', color='green')
plt.xlabel('Epoch')
plt.ylabel('Error [CrosEntr]')
plt.legend()
plt.grid(True)

plt.subplot(1, 2, 2)
plt.plot(train_acc, label='accuracy', color='red')
plt.xlabel('Epoch')
plt.ylabel('accuracy')
plt.legend()
plt.grid(True)
